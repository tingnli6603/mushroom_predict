# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#選擇圖形樣式
# %matplotlib inline
plt.style.use('fivethirtyeight')

import warnings
#忽略警告，為了排版整齊
warnings.filterwarnings('ignore')

#資料集切割
from sklearn.model_selection import train_test_split

#自訂方法
from sklearn.base import TransformerMixin

#變數標籤轉換
from sklearn.preprocessing import LabelEncoder

#機器學習管線
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV

#機器學習模型
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

#特徵選擇
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %% [markdown]
# ### 基本資料
#
# 自變數:22個，皆為類別變數；因變數:1個，為類別變數。__是為類別變數的分類目的__
#
# 資料筆數: 8416 筆

# %%
data_path = "./data/mushroom_dataset.csv"
mushroom_df = pd.read_csv(data_path)

mushroom_df
# Out:
#      cap-shape cap-surface cap-color  bruises    odor gill-attachment  \
# 0       CONVEX      SMOOTH     WHITE  BRUISES  ALMOND            FREE
# 1       CONVEX      SMOOTH     WHITE  BRUISES  ALMOND            FREE
# 2       CONVEX      SMOOTH     WHITE  BRUISES  ALMOND            FREE
# 3       CONVEX      SMOOTH     WHITE  BRUISES  ALMOND            FREE
# 4       CONVEX      SMOOTH     WHITE  BRUISES  ALMOND            FREE
# ...        ...         ...       ...      ...     ...             ...
# 8411   KNOBBED      SMOOTH     BROWN       NO    NONE        ATTACHED
# 8412   KNOBBED      SMOOTH     BROWN       NO    NONE        ATTACHED
# 8413   KNOBBED      SMOOTH     BROWN       NO    NONE        ATTACHED
# 8414   KNOBBED      SMOOTH     BROWN       NO    NONE        ATTACHED
# 8415   KNOBBED      SMOOTH     BROWN       NO    NONE        ATTACHED
#
#      gill-spacing gill-size gill-color stalk-shape  ...  \
# 0         CROWDED    NARROW      WHITE    TAPERING  ...
# 1         CROWDED    NARROW      WHITE    TAPERING  ...
# 2         CROWDED    NARROW       PINK    TAPERING  ...
# 3         CROWDED    NARROW       PINK    TAPERING  ...
# 4         CROWDED    NARROW      BROWN    TAPERING  ...
# ...           ...       ...        ...         ...  ...
# 8411        CLOSE     BROAD      BROWN   ENLARGING  ...
# 8412        CLOSE     BROAD      BROWN   ENLARGING  ...
# 8413        CLOSE     BROAD      BROWN   ENLARGING  ...
# 8414        CLOSE     BROAD      BROWN   ENLARGING  ...
# 8415        CLOSE     BROAD      BROWN   ENLARGING  ...
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                     WHITE                  WHITE   PARTIAL      WHITE
# 1                     WHITE                  WHITE   PARTIAL      WHITE
# 2                     WHITE                  WHITE   PARTIAL      WHITE
# 3                     WHITE                  WHITE   PARTIAL      WHITE
# 4                     WHITE                  WHITE   PARTIAL      WHITE
# ...                     ...                    ...       ...        ...
# 8411                 ORANGE                 ORANGE   PARTIAL      BROWN
# 8412                 ORANGE                 ORANGE   PARTIAL      BROWN
# 8413                 ORANGE                 ORANGE   PARTIAL      BROWN
# 8414                 ORANGE                 ORANGE   PARTIAL      BROWN
# 8415                 ORANGE                 ORANGE   PARTIAL      BROWN
#
#      ring-number ring-type spore-print-color population habitat mushroom
# 0            ONE   PENDANT            PURPLE    SEVERAL   WOODS   EDIBLE
# 1            ONE   PENDANT             BROWN    SEVERAL   WOODS   EDIBLE
# 2            ONE   PENDANT            PURPLE    SEVERAL   WOODS   EDIBLE
# 3            ONE   PENDANT             BROWN    SEVERAL   WOODS   EDIBLE
# 4            ONE   PENDANT            PURPLE    SEVERAL   WOODS   EDIBLE
# ...          ...       ...               ...        ...     ...      ...
# 8411         ONE   PENDANT             BROWN  CLUSTERED  LEAVES   EDIBLE
# 8412         ONE   PENDANT            ORANGE    SEVERAL  LEAVES   EDIBLE
# 8413         ONE   PENDANT            ORANGE  CLUSTERED  LEAVES   EDIBLE
# 8414         ONE   PENDANT              BUFF    SEVERAL  LEAVES   EDIBLE
# 8415         ONE   PENDANT              BUFF  CLUSTERED  LEAVES   EDIBLE
#
# [8416 rows x 23 columns]

# %% [markdown]
# ### 切分資料集
#
# 將訓練與測試資料切割，訓練80%、測試20%

# %%
train_df, test_df = train_test_split(mushroom_df, test_size=0.2)

print(train_df.shape, test_df.shape)
# Out:
# (6732, 23) (1684, 23)

# %% [markdown]
# ### 遺漏值觀察
#
# 訓練資料與測試資料皆無遺漏值

# %%
print(train_df.isnull().sum())
print(test_df.isnull().sum())
# Out:
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# mushroom                    0
# dtype: int64
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# mushroom                    0
# dtype: int64

# %% [markdown]
# ### 變數轉換

# %%
#自訂轉換方法
class LabelEncoderAll(TransformerMixin):
    def __init__(self, cols=None):
        self.cols = cols
        
    def transform(self, df):
        labelencoder = LabelEncoder()
        X = df.copy()
        
        for column_name in X.columns:
            X[column_name] = labelencoder.fit_transform(X[column_name])
            
        return X
    
    def fit(self, *_):
        return self

# %%
label_encoder_all = LabelEncoderAll()

# %%
#觀察欄位與標籤
labelencoder = LabelEncoder()
train_lea = train_df.copy()

for column_name in train_lea.columns:
    print(column_name)
    train_lea[column_name] = labelencoder.fit_transform(train_lea[column_name])
    print(list(labelencoder.classes_))
# Out:
# cap-shape
# ['BELL', 'CONICAL', 'CONVEX', 'FLAT', 'KNOBBED', 'SUNKEN']
# cap-surface
# ['FIBROUS', 'GROOVES', 'SCALY', 'SMOOTH']
# cap-color
# ['BROWN', 'BUFF', 'CINNAMON', 'GRAY', 'GREEN', 'PINK', 'PURPLE', 'RED', 'WHITE', 'YELLOW']
# bruises
# ['BRUISES', 'NO']
# odor
# ['ALMOND', 'ANISE', 'CREOSOTE', 'FISHY', 'FOUL', 'MUSTY', 'NONE', 'PUNGENT', 'SPICY']
# gill-attachment
# ['ATTACHED', 'FREE']
# gill-spacing
# ['CLOSE', 'CROWDED']
# gill-size
# ['BROAD', 'NARROW']
# gill-color
# ['BLACK', 'BROWN', 'BUFF', 'CHOCOLATE', 'GRAY', 'GREEN', 'ORANGE', 'PINK', 'PURPLE', 'RED', 'WHITE', 'YELLOW']
# stalk-shape
# ['ENLARGING', 'TAPERING']
# stalk-root
# ['?', 'BULBOUS', 'CLUB', 'EQUAL', 'ROOTED']
# stalk-surface-above-ring
# ['FIBROUS', 'SCALY', 'SILKY', 'SMOOTH']
# stalk-surface-below-ring
# ['FIBROUS', 'SCALY', 'SILKY', 'SMOOTH']
# stalk-color-above-ring
# ['BROWN', 'BUFF', 'CINNAMON', 'GRAY', 'ORANGE', 'PINK', 'RED', 'WHITE', 'YELLOW']
# stalk-color-below-ring
# ['BROWN', 'BUFF', 'CINNAMON', 'GRAY', 'ORANGE', 'PINK', 'RED', 'WHITE', 'YELLOW']
# veil-type
# ['PARTIAL']
# veil-color
# ['BROWN', 'ORANGE', 'WHITE', 'YELLOW']
# ring-number
# ['NONE', 'ONE', 'TWO']
# ring-type
# ['EVANESCENT', 'FLARING', 'LARGE', 'NONE', 'PENDANT']
# spore-print-color
# ['BLACK', 'BROWN', 'BUFF', 'CHOCOLATE', 'GREEN', 'ORANGE', 'PURPLE', 'WHITE', 'YELLOW']
# population
# ['ABUNDANT', 'CLUSTERED', 'NUMEROUS', 'SCATTERED', 'SEVERAL', 'SOLITARY']
# habitat
# ['GRASSES', 'LEAVES', 'MEADOWS', 'PATHS', 'URBAN', 'WASTE', 'WOODS']
# mushroom
# ['EDIBLE', 'POISONOUS']

# %% [markdown]
# ## 分類方法選擇

# %%
#空準確率，約為53%
train_df['mushroom'].value_counts(normalize=True)
# Out:
# EDIBLE       0.531788
# POISONOUS    0.468212
# Name: mushroom, dtype: float64

# %%
#最佳模型選擇
def get_best_model_and_accuracy(model, params, X, y):
    
    grid = GridSearchCV(model,
                       params,
                       error_score=0.)
    grid.fit(X, y)
    
    print("Best Accuracy: {}".format(grid.best_score_))
    print("Best Parameters: {}".format(grid.best_params_))

# %%
#切分X,y，分成train data與test data
train_X = train_df.drop('mushroom', axis=1)
train_y = train_df['mushroom']

test_X = test_df.drop('mushroom', axis=1)
test_y = test_df['mushroom']

train_X
# Out:
#      cap-shape cap-surface cap-color  bruises     odor gill-attachment  \
# 1978      FLAT     FIBROUS     WHITE       NO     NONE            FREE
# 2890    CONVEX       SCALY       RED  BRUISES     NONE            FREE
# 5056      FLAT     FIBROUS    YELLOW       NO     FOUL            FREE
# 7306   KNOBBED      SMOOTH       RED       NO    FISHY            FREE
# 7633   KNOBBED       SCALY       RED       NO    FISHY            FREE
# ...        ...         ...       ...      ...      ...             ...
# 1629    CONVEX     FIBROUS     BROWN       NO     NONE            FREE
# 5686      FLAT      SMOOTH      BUFF  BRUISES     FOUL            FREE
# 505     CONVEX       SCALY     WHITE  BRUISES   ALMOND            FREE
# 983     CONVEX       SCALY     WHITE  BRUISES  PUNGENT            FREE
# 1085      FLAT      SMOOTH     BROWN  BRUISES  PUNGENT            FREE
#
#      gill-spacing gill-size gill-color stalk-shape  ...  \
# 1978      CROWDED     BROAD      BROWN    TAPERING  ...
# 2890        CLOSE     BROAD      BROWN    TAPERING  ...
# 5056        CLOSE     BROAD  CHOCOLATE   ENLARGING  ...
# 7306        CLOSE    NARROW       BUFF    TAPERING  ...
# 7633        CLOSE    NARROW       BUFF    TAPERING  ...
# ...           ...       ...        ...         ...  ...
# 1629      CROWDED     BROAD  CHOCOLATE    TAPERING  ...
# 5686        CLOSE     BROAD      WHITE    TAPERING  ...
# 505         CLOSE     BROAD      BROWN   ENLARGING  ...
# 983         CLOSE    NARROW      BLACK   ENLARGING  ...
# 1085        CLOSE    NARROW      BROWN   ENLARGING  ...
#
#      stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring  \
# 1978                   SMOOTH                  WHITE                  WHITE
# 2890                   SMOOTH                   GRAY                   PINK
# 5056                    SILKY                  BROWN                   PINK
# 7306                   SMOOTH                  WHITE                  WHITE
# 7633                    SILKY                  WHITE                   PINK
# ...                       ...                    ...                    ...
# 1629                  FIBROUS                  WHITE                  WHITE
# 5686                  FIBROUS                  WHITE                  WHITE
# 505                    SMOOTH                  WHITE                  WHITE
# 983                    SMOOTH                  WHITE                  WHITE
# 1085                   SMOOTH                  WHITE                  WHITE
#
#      veil-type veil-color ring-number   ring-type spore-print-color  \
# 1978   PARTIAL      WHITE         ONE  EVANESCENT             BROWN
# 2890   PARTIAL      WHITE         ONE     PENDANT             BROWN
# 5056   PARTIAL      WHITE         ONE       LARGE         CHOCOLATE
# 7306   PARTIAL      WHITE         ONE  EVANESCENT             WHITE
# 7633   PARTIAL      WHITE         ONE  EVANESCENT             WHITE
# ...        ...        ...         ...         ...               ...
# 1629   PARTIAL      WHITE         ONE  EVANESCENT             BLACK
# 5686   PARTIAL      WHITE         ONE     PENDANT         CHOCOLATE
# 505    PARTIAL      WHITE         ONE     PENDANT             BLACK
# 983    PARTIAL      WHITE         ONE     PENDANT             BROWN
# 1085   PARTIAL      WHITE         ONE     PENDANT             BROWN
#
#      population  habitat
# 1978  SCATTERED  GRASSES
# 2890   SOLITARY    WOODS
# 5056   SOLITARY  GRASSES
# 7306    SEVERAL    WOODS
# 7633    SEVERAL    WOODS
# ...         ...      ...
# 1629   ABUNDANT  GRASSES
# 5686    SEVERAL    URBAN
# 505   SCATTERED  GRASSES
# 983     SEVERAL  GRASSES
# 1085  SCATTERED  GRASSES
#
# [6732 rows x 22 columns]

# %% [markdown]
# ### 分類模型

# %%
#邏輯斯迴歸
print("Logstic Regression")
lr = LogisticRegression()
lr_params = {'clf__C':[1e-1, 1e0, 1e1, 1e2], 'clf__penalty':['l1','l2']}

pipe_lr = Pipeline([('label_encoder',label_encoder_all),('clf', lr)])

get_best_model_and_accuracy(pipe_lr, lr_params, train_X, train_y)
# Out:
# Logstic Regression
# Best Accuracy: 0.959594431960959
# Best Parameters: {'clf__C': 100.0, 'clf__penalty': 'l2'}

# %%
#決策樹
print("dscision tree")
d_tree = DecisionTreeClassifier()
tree_params = {'clf__max_depth':[None, 1, 3, 5, 7]}

pipe_tree = Pipeline([('label_encoder',label_encoder_all),('clf', d_tree)])
get_best_model_and_accuracy(pipe_tree, tree_params, train_X, train_y)
# Out:
# dscision tree
# Best Accuracy: 0.9903417533432393
# Best Parameters: {'clf__max_depth': 7}

# %%
#隨機森林
print("random forest")
forest = RandomForestClassifier()
forest_params = {'clf__n_estimators':[10, 50, 100], 'clf__max_depth':[None, 1, 3, 5, 7]}

pipe_forest = Pipeline([('label_encoder',label_encoder_all),('clf', forest)])
get_best_model_and_accuracy(pipe_forest, forest_params, train_X, train_y)
# Out:
# random forest
# Best Accuracy: 1.0
# Best Parameters: {'clf__max_depth': None, 'clf__n_estimators': 50}

# %% [markdown]
# ### 模型訓練及應用到測試資料

# %%
pipe = Pipeline([('label_encoder',label_encoder_all),('clf', forest)])

pipe.set_params(clf__max_depth=None, clf__n_estimators=10)
pipe.fit(train_X, train_y)
pipe.score(test_X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-d8898c2b422c> in <module>
#       3 pipe.set_params(clf__max_depth=None, clf__n_estimators=10)
#       4 pipe.fit(train_X, train_y)
# ----> 5 pipe.score(test_X)
#
# c:\python38\lib\site-packages\sklearn\utils\metaestimators.py in <lambda>(*args, **kwargs)
#     117
#     118         # lambda, but not partial, allows help() to work with update_wrapper
# --> 119         out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)
#     120         # update the docstring of the returned function
#     121         update_wrapper(out, self.fn)
#
# c:\python38\lib\site-packages\sklearn\pipeline.py in score(self, X, y, sample_weight)
#     609         if sample_weight is not None:
#     610             score_params['sample_weight'] = sample_weight
# --> 611         return self.steps[-1][-1].score(Xt, y, **score_params)
#     612
#     613     @property
#
# c:\python38\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     497         """
#     498         from .metrics import accuracy_score
# --> 499         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     500
#     501     def _more_tags(self):
#
# c:\python38\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# c:\python38\lib\site-packages\sklearn\metrics\_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     185
#     186     # Compute accuracy for each possible representation
# --> 187     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     188     check_consistent_length(y_true, y_pred, sample_weight)
#     189     if y_type.startswith('multilabel'):
#
# c:\python38\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#      80     """
#      81     check_consistent_length(y_true, y_pred)
# ---> 82     type_true = type_of_target(y_true)
#      83     type_pred = type_of_target(y_pred)
#      84
#
# c:\python38\lib\site-packages\sklearn\utils\multiclass.py in type_of_target(y)
#     241
#     242     if not valid:
# --> 243         raise ValueError('Expected array-like (array or non-string sequence), '
#     244                          'got %r' % y)
#     245
#
# ValueError: Expected array-like (array or non-string sequence), got None
